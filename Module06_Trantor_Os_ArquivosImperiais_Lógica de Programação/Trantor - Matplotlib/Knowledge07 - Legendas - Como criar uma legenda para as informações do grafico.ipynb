# %% [markdown]
# # Mundo 7 - Como criar legendas em um gráfico

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# %%
params = {"ytick.color" : "w",
          "xtick.color" : "w",
          "axes.labelcolor" : "w",
          "axes.edgecolor" : "w"}
plt.rcParams.update(params)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cotacoes = yf.download(["WEGE3.SA", "PETR4.SA", "VALE3.SA", "LREN3.SA"])['Adj Close']

fig, ax = plt.subplots()

for empresa in cotacoes.columns:
      
    ax.plot(cotacoes.index, cotacoes[empresa].values, label = empresa)

ax.legend(loc = 10)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercícios
#
# * Exercício 96: Peça para o usuário digitar o código de 4 ações e plote um gráfico de linha com a legenda de cada ação.

# %%
#gabarito 96

acao1 = str(input("Escolha a 1º ação: "))
acao2 = str(input("Escolha a 2º ação: "))
acao3 = str(input("Escolha a 3º ação: "))
acao4 = str(input("Escolha a 4º ação: "))

lista_acoes = [acao1, acao2, acao3, acao4]

lista_acoes = [acao + ".SA" for acao in lista_acoes]

base_dados = yf.download(lista_acoes)['Adj Close']

fig, ax = plt.subplots()

for empresa in base_dados.columns:
      
    ax.plot(base_dados.index, base_dados[empresa].values, label = empresa.upper())

ax.legend(loc = 0)

# %% [markdown]
# # Mundo 8
#
# Como configurar eixos no gráfico? Colocar em %, R$, etc?
