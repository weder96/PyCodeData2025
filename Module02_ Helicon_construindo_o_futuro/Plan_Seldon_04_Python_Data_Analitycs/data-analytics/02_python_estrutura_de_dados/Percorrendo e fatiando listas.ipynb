# %%
#Percorrendo uma lista com for

carros = ['gol', 'saveiro', 'compass']

for carro in carros:
  print(carro)
# Out:
# gol
# saveiro
# compass

# %%
#Percorrendo usando range de listas
carros = ['gol', 'saveiro', 'compass']

for x in range(len(carros)):
  print(carros[x])
# Out:
# gol
# saveiro
# compass

# %%
#Fatiamento de listas

compras = ['arroz', 'feijão', 'farinha de trigo', 'açúcar', 'manteiga']
print(compras)

print(compras[0:2])
print(compras[:])
print(compras[-1])
print(compras[2:4])
print(compras[0:6:2])
print(compras[-1::-1])
# Out:
# ['arroz', 'feijão', 'farinha de trigo', 'açúcar', 'manteiga']
# ['arroz', 'feijão']
# ['arroz', 'feijão', 'farinha de trigo', 'açúcar', 'manteiga']
# manteiga
# ['farinha de trigo', 'açúcar']
# ['arroz', 'farinha de trigo', 'manteiga']
# ['manteiga', 'açúcar', 'farinha de trigo', 'feijão', 'arroz']
