# %% [markdown]
# # Aula 4.5 – O que são Quartis?
#
# Nesta aula, você vai aprender o que são quartis, como usá-los na prática com Pandas e por que eles são úteis para análise de dados.

# %% [markdown]
# ## 📊 O que são Quartis
#
# Imagine uma fila de 100 pessoas ordenadas por altura.
# Se você dividir essa fila em 4 partes iguais, cada parte terá 25 pessoas.
#
# Quartis dividem os dados ordenados em quatro partes iguais:
# - **Q1 (1º quartil)**: 25% dos dados estão abaixo
# - **Q2 (Mediana)**: 50% dos dados estão abaixo
# - **Q3 (3º quartil)**: 75% dos dados estão abaixo
#
# ![QT5.JPG](data:image/jpeg;base64,...)
#
#
#
#
# **Objetivo:**
#
#     ✅ Entender a distribuição dos dados
#     ✅ Detectar outliers (valores extremos)
#     ✅ Segmentar dados em faixas (ex: clientes de baixo/médio/alto valor)
#     ✅ Criar gráficos tipo boxplot
#     ✅ Fazer análises comparativas com mais contexto

# %%
import pandas as pd

# Carregar base de dados
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'
df = pd.read_csv(url)

# Exibir primeiras linhas
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 📐 Calculando os Quartis
# Vamos aplicar a função `quantile()` no campo `total_bill`.

# %%
quartis = df['total_bill'].quantile([0.25, 0.5, 0.75])
print("Quartis:")
print(quartis)
# Out:
# Quartis:
# 0.25    13.3475
# 0.50    17.7950
# 0.75    24.1275
# Name: total_bill, dtype: float64

# %%
quartis = df['tip'].quantile([0.25, 0.5, 0.75])
print("Quartis:")
print(quartis)
# Out:
# Quartis:
# 0.25    2.0000
# 0.50    2.9000
# 0.75    3.5625
# Name: tip, dtype: float64

# %%
df['total_bill'].mean()
# Out:
# np.float64(19.78594262295082)

# %%
df['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %% [markdown]
# ## 📦 Classificando por Quartis
# Você também pode usar `qcut()` para categorizar os dados em faixas baseadas nos quartis.

# %%
df['segmento'] = pd.qcut(df['total_bill'], q=4, labels=['baixo', 'médio-baixo', 'médio-alto', 'alto'])
df[['total_bill', 'segmento']].head()
# Out:
#    total_bill     segmento
# 0       16.99  médio-baixo
# 1       10.34        baixo
# 2       21.01   médio-alto
# 3       23.68   médio-alto
# 4       24.59         alto

# %% [markdown]
# ## 🧩 Casos Reais de Aplicação
# - **Varejo**: Classificar clientes por gasto.
# - **Educação**: Agrupar alunos por nota.
# - **RH**: Analisar salários.
# - **Finanças**: Segmentar investimentos.
#
# Quartis são uma ferramenta poderosa para entender padrões e tomar decisões com base em dados.

# %% [markdown]
# ## 🧪 Atividade Prática
# - Calcule os quartis da coluna `tip`.
# - Crie uma nova coluna `segmento_tip` com a classificação dos valores de `tip` em 4 categorias usando `qcut()`.

# %%
# Seu código aqui
quartis_tip = df['tip'].quantile([0.25, 0.5, 0.75])
df['segmento_tip'] = pd.qcut(df['tip'], q=4, labels=['baixo', 'médio-baixo', 'médio-alto', 'alto'])
df[['tip', 'segmento_tip']].head()

# %% [markdown]
# ## ✅ Conclusão
# Você aprendeu o que são quartis, como calcular e aplicar em segmentações com Pandas, e viu exemplos reais de uso. Eles serão muito úteis nas próximas etapas da sua análise de dados.
