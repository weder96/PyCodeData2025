# %% [markdown]
# # Usando SQLite no Google Colab com dados de CSV
#
# Vamos **carregar um arquivo CSV com pandas**, transformá-lo em uma **tabela SQLite**, e então usar SQL para consultar os dados.
#
# 📌 Isso é muito útil para aplicar SQL em planilhas ou arquivos CSV que você já possui.

# %% [markdown]
# ## Passo 1 – Carregar o CSV com pandas

# %%
import pandas as pd

# Substitua pelo nome do arquivo enviado
df = pd.read_csv("clientes_dataset.csv")
df.head()
# Out:
#    cliente_id              nome                          email  idade  \
# 0           1      Norma Fisher      christopherbond@yahoo.com     62
# 1           2    Jorge Sullivan               jeaton@yahoo.com     65
# 2           3   Elizabeth Woods       mfuller@jones-taylor.com     18
# 3           4      Susan Wagner             lauren75@gmail.com     21
# 4           5  Peter Montgomery  tdaugherty@pratt-crawford.com     21
#
#          cidade estado data_ultima_compra  total_gasto  frequencia_compras  \
# 0  Elliottmouth     NJ         2025-01-26      4635.94                  21
# 1     East Adam     PA         2024-05-24      1615.33                   5
# 2     Whitetown     GA         2024-09-29      2075.77                  13
# 3     Jamesside     RI         2025-01-03      3202.00                  22
# 4  Heidiborough     TN         2024-11-28      4464.20                  18
#
#   forma_pagamento  satisfacao  cliente_ativo
# 0         Crédito           1          False
# 1          Boleto           4          False
# 2          Boleto           3           True
# 3          Débito           5          False
# 4         Crédito           5           True

# %% [markdown]
# ## Passo 2 – Enviar o DataFrame para um banco SQLite

# %%
import sqlite3

# Criar banco em memória
conn = sqlite3.connect(':memory:')

# Enviar o DataFrame como tabela chamada 'clientes'
df.to_sql("clientes", conn, index=False, if_exists="replace")
# Out:
# 1000

# %% [markdown]
# ## Passo 3 – Consultar a tabela com SQL usando pandas

# %%
df_sql = pd.read_sql_query("SELECT * FROM clientes", conn)
df_sql.head()
# Out:
#    cliente_id              nome                          email  idade  \
# 0           1      Norma Fisher      christopherbond@yahoo.com     62
# 1           2    Jorge Sullivan               jeaton@yahoo.com     65
# 2           3   Elizabeth Woods       mfuller@jones-taylor.com     18
# 3           4      Susan Wagner             lauren75@gmail.com     21
# 4           5  Peter Montgomery  tdaugherty@pratt-crawford.com     21
#
#          cidade estado data_ultima_compra  total_gasto  frequencia_compras  \
# 0  Elliottmouth     NJ         2025-01-26      4635.94                  21
# 1     East Adam     PA         2024-05-24      1615.33                   5
# 2     Whitetown     GA         2024-09-29      2075.77                  13
# 3     Jamesside     RI         2025-01-03      3202.00                  22
# 4  Heidiborough     TN         2024-11-28      4464.20                  18
#
#   forma_pagamento  satisfacao  cliente_ativo
# 0         Crédito           1              0
# 1          Boleto           4              0
# 2          Boleto           3              1
# 3          Débito           5              0
# 4         Crédito           5              1

# %% [markdown]
# ## Exemplos de consultas

# %%
# Filtro com WHERE
df_sql_2 = pd.read_sql_query("SELECT * FROM clientes WHERE idade > 30", conn)
df_sql_2.head()
# Out:
#    cliente_id              nome                      email  idade  \
# 0           1      Norma Fisher  christopherbond@yahoo.com     62
# 1           2    Jorge Sullivan           jeaton@yahoo.com     65
# 2           6  Theodore Mcgrath          grant52@yahoo.com     57
# 3           8  Stephanie Sutton      melissa03@hotmail.com     37
# 4           9    Brian Hamilton    geoffreygrant@yahoo.com     39
#
#             cidade estado data_ultima_compra  total_gasto  frequencia_compras  \
# 0     Elliottmouth     NJ         2025-01-26      4635.94                  21
# 1        East Adam     PA         2024-05-24      1615.33                   5
# 2  East Josephberg     CA         2024-05-08      2219.77                  23
# 3     Wyattborough     AK         2024-07-28      3001.20                  16
# 4   New Kendraview     PA         2024-10-14      2215.75                   7
#
#   forma_pagamento  satisfacao  cliente_ativo
# 0         Crédito           1              0
# 1          Boleto           4              0
# 2         Crédito           3              1
# 3             Pix           3              1
# 4         Crédito           3              1

# %%
df_sql_2.describe()
# Out:
#         cliente_id       idade  total_gasto  frequencia_compras  satisfacao  \
# count   734.000000  734.000000   734.000000          734.000000  734.000000
# mean    498.554496   50.299728  2528.485708           12.348774    3.332425
# std     287.701047   11.201007  1437.572663            6.677804    1.259555
# min       1.000000   31.000000   100.300000            1.000000    1.000000
# 25%     250.250000   41.000000  1286.817500            7.000000    2.000000
# 50%     491.500000   50.500000  2562.780000           12.000000    4.000000
# 75%     747.750000   60.000000  3764.600000           18.000000    4.000000
# max    1000.000000   69.000000  4999.280000           24.000000    5.000000
#
#        cliente_ativo
# count     734.000000
# mean        0.685286
# std         0.464719
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
df_sql = pd.read_sql_query("SELECT nome, idade FROM clientes", conn)
df_sql.head()
# Out:
#                nome  idade
# 0      Norma Fisher     62
# 1    Jorge Sullivan     65
# 2   Elizabeth Woods     18
# 3      Susan Wagner     21
# 4  Peter Montgomery     21

# %% [markdown]
# ## Conclusão
# - Essa é uma forma prática de aplicar SQL em qualquer CSV
# - Você combina a familiaridade do pandas com o poder das consultas SQL
# - Ideal para análises, filtros, dashboards e ETL leve
