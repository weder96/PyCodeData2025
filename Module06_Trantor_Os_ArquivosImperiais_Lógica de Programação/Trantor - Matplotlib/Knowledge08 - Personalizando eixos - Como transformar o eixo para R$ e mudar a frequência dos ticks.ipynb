# %% [markdown]
# # Knowledge 8 - Como personalizar os eixos do gráfico (R$, %)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#colocando o eixo Y em reais e na cor branca

cotacoes = yf.download(["WEGE3.SA"])['Close']

fig, ax = plt.subplots()

ax.plot(cotacoes.index, cotacoes.values)
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')
ax.yaxis.set_major_formatter('R${x:1.0f}')
# Out:
# /tmp/ipykernel_15800/1052583697.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cotacoes = yf.download(["WEGE3.SA"])['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
#Mudando a ocorrência das datas no eixo X

import matplotlib.dates as mdate

cotacoes = yf.download(["WEGE3.SA"], "2010-01-01")['Close']

fig, ax = plt.subplots()

ax.plot(cotacoes.index, cotacoes.values)
ax.xaxis.set_major_locator(mdate.YearLocator(2))
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')
# Out:
# /tmp/ipykernel_15800/4235885878.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cotacoes = yf.download(["WEGE3.SA"], "2010-01-01")['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
#Mudando o formato das datas no eixo X

cotacoes = yf.download(["WEGE3.SA"], "2019-01-01")['Close']

fig, ax = plt.subplots()

ax.plot(cotacoes.index, cotacoes.values)
minha_formatacao = mdate.DateFormatter('%b-%y')
ax.xaxis.set_major_formatter(minha_formatacao)

plt.xticks(rotation=45)
ax.xaxis.set_major_locator(mdate.MonthLocator(interval = 6))
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')

plt.show()
# Out:
# /tmp/ipykernel_15800/462723301.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cotacoes = yf.download(["WEGE3.SA"], "2019-01-01")['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
#colocando o eixo em %

import matplotlib.ticker as mtick

cotacoes = yf.download(["WEGE3.SA"], "2015-01-01")['Close']

retornos = cotacoes.pct_change().dropna()

retornos_acumulados = (1 + retornos).cumprod() - 1

fig, ax = plt.subplots()

ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')
ax.plot(retornos_acumulados.index, retornos_acumulados.values)

ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
# Out:
# /tmp/ipykernel_15800/4047252751.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cotacoes = yf.download(["WEGE3.SA"], "2015-01-01")['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
#mudando a frequencia dos ticks que não são datas

cotacoes = yf.download(["WEGE3.SA"], "2015-01-01")['Close']

retornos = cotacoes.pct_change().dropna()

retornos_acumulados = (1 + retornos).cumprod() - 1

dias = range(0, len(retornos_acumulados))

fig, ax = plt.subplots()

ax.plot(dias, retornos_acumulados.values)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')

ax.xaxis.set_ticks([0, 1000, 2000], ["Inicio", "Meio", "Fim"])

plt.show()
# Out:
# /tmp/ipykernel_15800/3109272965.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cotacoes = yf.download(["WEGE3.SA"], "2015-01-01")['Close']
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Exercícios
#
# * Exercício 97: Puxe os dados de cotação da Petrobras, crie um gráfico da linha com a evolução de cotação e configure o eixo Y como R$.
# * Exercício 98: Com os mesmos dados da Petrobras configure o eixo X para que o intervalo de tempo seja a cada dois anos. Além disso, mude o formato da data para dia-mes-ano.
# * Exercício 99: Calcule a rentabilidade acumulada da Petrobras no período, crie um gráfico de performance e configure o eixo X como %.

# %%
#gabarito 97

cotacoes = yf.download(["PETR4.SA"])['Close']

fig, ax = plt.subplots()

ax.plot(cotacoes.index, cotacoes.values)
ax.yaxis.set_major_formatter('R${x:1.0f}')
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')
# Out:
# /tmp/ipykernel_15800/3894301061.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cotacoes = yf.download(["PETR4.SA"])['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
#gabarito 98

fig, ax = plt.subplots()

ax.plot(cotacoes.index, cotacoes.values)
ax.yaxis.set_major_formatter('R${x:1.0f}')
myFmt = mdate.DateFormatter('%d-%b-%Y')
ax.xaxis.set_major_formatter(myFmt)
ax.xaxis.set_major_locator(mdate.YearLocator(2))
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')

# %%
#gabarito 99

retornos = cotacoes.pct_change().dropna()

retornos_acumulados = (1 + retornos).cumprod() - 1

fig, ax = plt.subplots()

ax.plot(retornos_acumulados.index, retornos_acumulados.values)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')

# %%
import yfinance as yf
import matplotlib.pyplot as plt


cotacoes = yf.download(["ITUB4.SA"], "2020-12-28", "2023-01-01")['Close']
cotacoes = cotacoes.dropna().resample("YE").mean()
cotacoes.index = ['2020', '2021', '2022']
cotacoes.plot.pie(title="Média Anual da Cotação ITUB4.SA", 
                  autopct='%1.1f%%', figsize=(8, 8),subplots=True)
plt.ylabel('')
plt.show()
# Out:
# /tmp/ipykernel_17204/928226914.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   cotacoes = yf.download(["ITUB4.SA"], "2020-12-28", "2023-01-01")['Close']
# [*********************100%***********************]  1 of 1 completed
